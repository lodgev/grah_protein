# %%
from neo4j import GraphDatabase
import random
from collections import defaultdict

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

# Connect to Neo4j
driver = GraphDatabase.driver(URI, auth=AUTH)

# Select test proteins: labeled proteins to hide their labels for validation
def select_test_proteins(tx, sample_size=100):
    query = """
    MATCH (p:Protein)
    WHERE p.ec_number IS NOT NULL
    RETURN p.entry AS entry, p.ec_number AS ec
    LIMIT $limit
    """
    result = tx.run(query, limit=sample_size)
    return [(record["entry"], record["ec"]) for record in result]

# Temporarily remove EC numbers from test proteins
def remove_labels(tx, test_entries):
    for entry in test_entries:
        tx.run("MATCH (p:Protein {entry: $entry}) SET p.true_ec = p.ec_number, p.ec_number = NULL", entry=entry)

# Restore original EC numbers after testing
def restore_labels(tx):
    tx.run("MATCH (p:Protein) WHERE p.true_ec IS NOT NULL SET p.ec_number = p.true_ec REMOVE p.true_ec")

# Perform label propagation and collect predicted labels
def annotate_protein(tx, entry_id, similarity_threshold=0.2):
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)
    ec_weights = defaultdict(float)
    for record in result:
        ec_weights[record["ec"]] += record["weight"]
    if ec_weights:
        return max(ec_weights, key=ec_weights.get)
    return None

# Run validation test
with driver.session() as session:
    test_proteins = session.execute_read(select_test_proteins, sample_size=100)
    session.execute_write(remove_labels, [entry for entry, _ in test_proteins])
    
    TP = 0
    P = 0
    T = 0

    for entry, true_ec in test_proteins:
        predicted_ec = session.execute_read(annotate_protein, entry)
        if predicted_ec:
            P += 1
            if predicted_ec == true_ec:
                TP += 1
        if true_ec:
            T += 1

    precision = TP / P if P else 0
    recall = TP / T if T else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0
    coverage = P / len(test_proteins)

    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print(f"Coverage: {coverage:.2f}")

    session.execute_write(restore_labels)

driver.close()
# Out:
# Precision: 0.91
# Recall: 0.86
# F1 Score: 0.88
# Coverage: 0.95

# %%
# Step 3
from neo4j import GraphDatabase

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

driver = GraphDatabase.driver(URI, auth=AUTH)

# Function to calculate EC label weights and select the best label for an unlabeled protein
def annotate_protein(tx, entry_id, similarity_threshold=0.2):
    # Find neighbors and their EC labels
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)

    ec_weights = {}

    # Calculate total weights for each EC label
    for record in result:
        ec = record["ec"]
        weight = record["weight"]
        if ec in ec_weights:
            ec_weights[ec] += weight
        else:
            ec_weights[ec] = weight

    # If annotated neighbors exist, choose the label with the highest weight
    if ec_weights:
        best_ec = max(ec_weights, key=ec_weights.get)
        # Update the protein with the selected label
        update_query = """
        MATCH (p:Protein {entry: $entry_id})
        SET p.ec_number = $ec
        RETURN p.entry, p.ec_number
        """
        updated = tx.run(update_query, entry_id=entry_id, ec=best_ec)
        return updated.single()
    else:
        return None

# Use the function with a specific protein
protein_to_annotate = 'A0A024R1X5'  # Replace with the protein entry you want to annotate

with driver.session() as session:
    annotation_result = session.execute_write(annotate_protein, protein_to_annotate)

    if annotation_result:
        print(f"Protein {annotation_result['p.entry']} successfully annotated as {annotation_result['p.ec_number']}")
    else:
        print(f"Not enough data to annotate protein {protein_to_annotate}")

driver.close()
# Out:
# Not enough data to annotate protein A0A024R1X5

# %%
from neo4j import GraphDatabase
import random
from collections import defaultdict

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

# Connect to Neo4j
driver = GraphDatabase.driver(URI, auth=AUTH)

# Select test proteins: labeled proteins to hide their labels for validation
def select_test_proteins(tx, sample_size=100):
    query = """
    MATCH (p:Protein)
    WHERE p.ec_number IS NOT NULL
    RETURN p.entry AS entry, p.ec_number AS ec
    LIMIT $limit
    """
    result = tx.run(query, limit=sample_size)
    return [(record["entry"], record["ec"]) for record in result]

# Temporarily remove EC numbers from test proteins
def remove_labels(tx, test_entries):
    for entry in test_entries:
        tx.run("MATCH (p:Protein {entry: $entry}) SET p.true_ec = p.ec_number, p.ec_number = NULL", entry=entry)

# Restore original EC numbers after testing
def restore_labels(tx):
    tx.run("MATCH (p:Protein) WHERE p.true_ec IS NOT NULL SET p.ec_number = p.true_ec REMOVE p.true_ec")

# Perform label propagation and collect top-N predicted labels
def annotate_protein_multilabel(tx, entry_id, similarity_threshold=0.2, top_n=3):
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)
    ec_weights = defaultdict(float)
    for record in result:
        ec_weights[record["ec"]] += record["weight"]
    if ec_weights:
        sorted_ecs = sorted(ec_weights.items(), key=lambda x: x[1], reverse=True)
        return [ec for ec, _ in sorted_ecs[:top_n]]
    return []

# Run validation test for multilabel prediction
with driver.session() as session:
    test_proteins = session.execute_read(select_test_proteins, sample_size=100)
    session.execute_write(remove_labels, [entry for entry, _ in test_proteins])

    TP = 0
    P = 0
    T = 0

    for entry, true_ec in test_proteins:
        predicted_ecs = session.execute_read(annotate_protein_multilabel, entry)
        if predicted_ecs:
            P += 1
            if true_ec in predicted_ecs:
                TP += 1
        if true_ec:
            T += 1

    precision = TP / P if P else 0
    recall = TP / T if T else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0
    coverage = P / len(test_proteins)

    print(f"[Multi-label] Precision: {precision:.2f}")
    print(f"[Multi-label] Recall: {recall:.2f}")
    print(f"[Multi-label] F1 Score: {f1:.2f}")
    print(f"[Multi-label] Coverage: {coverage:.2f}")

    session.execute_write(restore_labels)

driver.close()
# Out:
# [Multi-label] Precision: 0.94
# [Multi-label] Recall: 0.89
# [Multi-label] F1 Score: 0.91
# [Multi-label] Coverage: 0.95

# %%
from neo4j import GraphDatabase
import random
from collections import defaultdict

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

# Connect to Neo4j
driver = GraphDatabase.driver(URI, auth=AUTH)

# Select test proteins: labeled proteins to hide their labels for validation
def select_test_proteins(tx, sample_size=100):
    query = """
    MATCH (p:Protein)
    WHERE p.ec_number IS NOT NULL
    RETURN p.entry AS entry, p.ec_number AS ec
    LIMIT $limit
    """
    result = tx.run(query, limit=sample_size)
    return [(record["entry"], record["ec"]) for record in result]

# Temporarily remove EC numbers from test proteins
def remove_labels(tx, test_entries):
    for entry in test_entries:
        tx.run("MATCH (p:Protein {entry: $entry}) SET p.true_ec = p.ec_number, p.ec_number = NULL", entry=entry)

# Restore original EC numbers after testing
def restore_labels(tx):
    tx.run("MATCH (p:Protein) WHERE p.true_ec IS NOT NULL SET p.ec_number = p.true_ec REMOVE p.true_ec")

# Perform label propagation and collect top-N predicted labels or threshold-based labels (READ ONLY)
def annotate_protein_multilabel(tx, entry_id, similarity_threshold=0.2, top_n=3, min_weight=0.0):
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)
    ec_weights = defaultdict(float)
    for record in result:
        ec_raw = record["ec"]
        weight = record["weight"]
        ec_list = [ec.strip() for ec in ec_raw.split(';')]  # Split multi-labels from neighbor
        for ec in ec_list:
            ec_weights[ec] += weight

    filtered_ecs = [(ec, weight) for ec, weight in ec_weights.items() if weight >= min_weight]
    sorted_ecs = sorted(filtered_ecs, key=lambda x: x[1], reverse=True)
    top_ecs = [ec for ec, _ in sorted_ecs[:top_n]]
    return top_ecs

# Write predictions to Neo4j (WRITE ONLY)
def save_predictions(tx, entry_id, predictions):
    tx.run("MATCH (p:Protein {entry: $entry}) SET p.ec_predictions = $predictions", entry=entry_id, predictions=predictions)

# Run validation test for multilabel prediction with saving predictions in Neo4j
with driver.session() as session:
    test_proteins = session.execute_read(select_test_proteins, sample_size=100)
    session.execute_write(remove_labels, [entry for entry, _ in test_proteins])

    TP = 0
    P = 0
    T = 0

    for entry, true_ec in test_proteins:
        predicted_ecs = session.execute_read(annotate_protein_multilabel, entry, 0.2, 3, 0.1)
        if predicted_ecs:
            P += 1
            if true_ec in predicted_ecs:
                TP += 1
            session.execute_write(save_predictions, entry, predicted_ecs)
        if true_ec:
            T += 1

    precision = TP / P if P else 0
    recall = TP / T if T else 0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) else 0
    coverage = P / len(test_proteins)

    print(f"[Multi-label] Precision: {precision:.2f}")
    print(f"[Multi-label] Recall: {recall:.2f}")
    print(f"[Multi-label] F1 Score: {f1:.2f}")
    print(f"[Multi-label] Coverage: {coverage:.2f}")

    session.execute_write(restore_labels)

driver.close()
# Out:
# [Multi-label] Precision: 0.84
# [Multi-label] Recall: 0.80
# [Multi-label] F1 Score: 0.82
# [Multi-label] Coverage: 0.95

# %%
from neo4j import GraphDatabase
from collections import defaultdict

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

# Connect to Neo4j
driver = GraphDatabase.driver(URI, auth=AUTH)

# Function to retrieve all proteins with NULL ec_number
def get_unannotated_proteins(tx):
    query = """
    MATCH (p:Protein)
    WHERE p.ec_number IS NULL
    RETURN p.entry AS entry
    """
    result = tx.run(query)
    return [record["entry"] for record in result]

# Perform label propagation for given protein (multi-label)
def annotate_protein_multilabel(tx, entry_id, similarity_threshold=0.2, top_n=3, min_weight=0.0):
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)
    ec_weights = defaultdict(float)
    for record in result:
        ec_raw = record["ec"]
        weight = record["weight"]
        ec_list = [ec.strip() for ec in ec_raw.split(';')]
        for ec in ec_list:
            ec_weights[ec] += weight

    filtered_ecs = [(ec, weight) for ec, weight in ec_weights.items() if weight >= min_weight]
    sorted_ecs = sorted(filtered_ecs, key=lambda x: x[1], reverse=True)
    top_ecs = [ec for ec, _ in sorted_ecs[:top_n]]
    return top_ecs

# Save predictions to Neo4j
def save_predictions(tx, entry_id, predictions):
    tx.run("MATCH (p:Protein {entry: $entry}) SET p.ec_predictions = $predictions", entry=entry_id, predictions=predictions)

# Run annotation for all unannotated proteins
with driver.session() as session:
    entries = session.execute_read(get_unannotated_proteins)
    print(f"Found {len(entries)} unannotated proteins")

    for entry in entries:
        predicted_ecs = session.execute_read(annotate_protein_multilabel, entry, 0.2, 3, 0.1)
        if predicted_ecs:
            session.execute_write(save_predictions, entry, predicted_ecs)
            print(f"Saved predictions for {entry}: {predicted_ecs}")

driver.close()
# Out:
# Found 3281 unannotated proteins
# Saved predictions for A0A024R324: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for A0A024R7I7: ['3.6.5.2', '3.6.5.-']
# Saved predictions for A0A087X0K9: ['2.7.11.1']
# Saved predictions for A0A090N7W4: ['2.7.11.1', '2.7.11.22', '2.7.11.30']
# Saved predictions for A0A0C4DGF1: ['3.6.1.-']
# Saved predictions for A0A0K2S4Q6: ['3.2.2.6', '3.4.24.-']
# Saved predictions for A0A0S2Z3A9: ['2.4.1.255', '2.3.2.27']
# Saved predictions for A0A0S2Z3W6: ['7.2.2.13', '7.2.2.10', '7.6.2.1']
# Saved predictions for A0A0S2Z4Z8: ['2.7.11.1', '2.7.10.2', '2.7.12.2']
# Saved predictions for A0A0S2Z5X4: ['2.3.2.-']
# Saved predictions for A0A140VK09: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for A0A140VKC4: ['3.2.2.-']
# Saved predictions for A0A384P5C6: ['3.4.24.19']
# Saved predictions for A0A7I2PJA1: ['2.3.2.-']
# Saved predictions for A0A7I2R3P8: ['2.3.1.-', '2.7.11.1']
# Saved predictions for A0A8I5KZC4: ['2.4.2.-', '2.4.2.30']
# Saved predictions for A0A8Q3SHM6: ['3.1.1.13', '3.1.1.1', '3.1.1.56']
# Saved predictions for A0AVF1: ['2.4.1.255']
# Saved predictions for A0PJY2: ['2.3.2.-']
# Saved predictions for A1L4K1: ['2.3.2.27']
# Saved predictions for A2A2Y4: ['3.1.3.48', '2.7.10.1']
# Saved predictions for A2RUH7: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for A4D1T9: ['3.4.21.-', '3.4.21.4', '3.4.21.35']
# Saved predictions for A6NGQ3: ['2.7.10.1', '2.7.11.1']
# Saved predictions for A6NI73: ['2.7.10.1', '3.2.2.6']
# Saved predictions for A6NNZ2: ['3.6.5.-']
# Saved predictions for A8K4G0: ['3.2.2.6', '3.4.24.-']
# Saved predictions for A8K8V0: ['2.3.2.-']
# Saved predictions for A8MTJ3: ['3.6.5.-']
# Saved predictions for A8MU46: ['1.14.13.225']
# Saved predictions for A8MVW5: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for A9YTQ3: ['2.3.1.48']
# Saved predictions for B2RXF5: ['2.3.2.-', '3.6.1.-']
# Saved predictions for B6A8C7: ['3.2.2.6']
# Saved predictions for D0VY79: ['2.3.1.48']
# Saved predictions for D9ZGF9: ['3.1.-.-']
# Saved predictions for K9JA46: ['3.6.4.10']
# Saved predictions for O00139: ['3.6.4.-', '2.7.10.1']
# Saved predictions for O00170: ['5.2.1.8']
# Saved predictions for O00178: ['3.6.5.-', '3.6.5.3']
# Saved predictions for O00212: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for O00221: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for O00233: ['3.4.21.108']
# Saved predictions for O00241: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O00264: ['1.14.19.44', '1.14.19.3']
# Saved predictions for O00327: ['2.3.1.48']
# Saved predictions for O00330: ['2.3.1.12', '2.3.1.168', '2.3.1.61']
# Saved predictions for O00445: ['3.1.1.4', '3.1.3.66', '3.1.1.5']
# Saved predictions for O00478: ['2.3.2.27']
# Saved predictions for O00481: ['2.3.2.27']
# Saved predictions for O00488: ['2.3.2.-']
# Saved predictions for O00533: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O00548: ['3.4.24.19']
# Saved predictions for O00560: ['3.4.21.108']
# Saved predictions for O00623: ['2.3.2.27']
# Saved predictions for O14511: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O14523: ['3.1.3.66']
# Saved predictions for O14530: ['1.11.1.24', '5.3.4.1', '1.8.4.2']
# Saved predictions for O14593: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for O14618: ['1.15.1.1']
# Saved predictions for O14628: ['2.3.2.-']
# Saved predictions for O14782: ['3.6.4.-', '2.7.10.1', '5.6.1.3']
# Saved predictions for O14879: ['2.4.1.255', '2.3.2.27']
# Saved predictions for O14901: ['2.3.2.-']
# Saved predictions for O14908: ['3.4.21.108']
# Saved predictions for O14931: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O14950: ['5.2.1.8', '1.1.5.3']
# Saved predictions for O14966: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for O14977: ['4.1.1.17']
# Saved predictions for O14979: ['3.1.3.36']
# Saved predictions for O15015: ['2.3.2.-']
# Saved predictions for O15018: ['3.4.21.108']
# Saved predictions for O15031: ['2.7.10.1']
# Saved predictions for O15060: ['2.3.2.-']
# Saved predictions for O15062: ['2.3.2.-']
# Saved predictions for O15066: ['3.6.4.-', '2.7.10.1', '5.6.1.3']
# Saved predictions for O15068: ['2.7.11.1']
# Saved predictions for O15084: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for O15156: ['2.3.2.-']
# Saved predictions for O15173: ['1.14.19.44', '1.14.19.3']
# Saved predictions for O15182: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for O15197: ['2.7.10.1']
# Saved predictions for O15209: ['2.3.2.-']
# Saved predictions for O15287: ['2.4.1.255']
# Saved predictions for O15372: ['3.4.19.-']
# Saved predictions for O15381: ['5.6.1.1', '3.6.4.6', '3.6.4.-']
# Saved predictions for O15389: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for O15391: ['2.3.2.-']
# Saved predictions for O15394: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O15492: ['2.7.11.16']
# Saved predictions for O15519: ['3.4.22.36', '3.4.22.57', '3.4.22.58']
# Saved predictions for O15535: ['2.3.2.-']
# Saved predictions for O15540: ['5.3.99.2']
# Saved predictions for O15553: ['2.3.2.27']
# Saved predictions for O43157: ['2.7.10.1']
# Saved predictions for O43167: ['2.3.2.-']
# Saved predictions for O43169: ['1.14.19.44', '1.14.19.3', '1.8.3.1']
# Saved predictions for O43187: ['2.7.11.1', '2.7.10.2']
# Saved predictions for O43189: ['1.14.11.66', '1.14.11.-', '1.14.11.69']
# Saved predictions for O43291: ['1.6.2.-']
# Saved predictions for O43296: ['2.3.2.-']
# Saved predictions for O43298: ['2.3.2.-']
# Saved predictions for O43300: ['3.1.3.16']
# Saved predictions for O43309: ['2.3.2.-']
# Saved predictions for O43396: ['5.3.4.1', '1.8.4.2']
# Saved predictions for O43474: ['2.3.2.-']
# Saved predictions for O43491: ['3.1.3.48', '2.7.10.1']
# Saved predictions for O43572: ['2.7.11.16']
# Saved predictions for O43581: ['3.1.3.66']
# Saved predictions for O43623: ['2.3.2.-']
# Saved predictions for O43670: ['2.3.2.-']
# Saved predictions for O43699: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O43745: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for O43765: ['2.4.1.255']
# Saved predictions for O43809: ['3.6.1.-', '3.6.1.77', '3.6.1.45']
# Saved predictions for O43819: ['1.11.1.24']
# Saved predictions for O43822: ['2.3.1.-', '2.7.11.1']
# Saved predictions for O43829: ['2.3.2.-']
# Saved predictions for O43837: ['1.1.1.42', '1.1.1.41']
# Saved predictions for O43852: ['3.1.3.16', '5.2.1.8', '1.1.5.3']
# Saved predictions for O43865: ['3.13.2.1']
# Saved predictions for O43896: ['5.6.1.3', '3.6.4.-']
# Saved predictions for O43918: ['1.14.11.-']
# Saved predictions for O60256: ['2.7.6.1', '2.4.2.8', '2.4.2.7']
# Saved predictions for O60281: ['2.3.2.-']
# Saved predictions for O60469: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O60481: ['2.3.2.-']
# Saved predictions for O60486: ['2.7.10.1']
# Saved predictions for O60487: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O60494: ['3.4.24.19', '3.4.24.-', '3.4.21.104']
# Saved predictions for O60500: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O60667: ['3.2.2.6']
# Saved predictions for O60706: ['7.6.2.-', '7.6.2.2', '7.6.2.3']
# Saved predictions for O60759: ['3.4.21.108']
# Saved predictions for O60828: ['2.3.2.26']
# Saved predictions for O60939: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O75015: ['3.2.2.6', '3.4.24.-', '2.7.10.1']
# Saved predictions for O75019: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for O75022: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for O75023: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for O75027: ['7.6.2.-', '7.6.2.2', '7.6.2.3']
# Saved predictions for O75037: ['2.7.10.1', '3.6.4.-']
# Saved predictions for O75051: ['2.7.10.1']
# Saved predictions for O75054: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for O75077: ['3.4.24.-', '3.4.24.81']
# Saved predictions for O75078: ['3.4.24.-', '3.4.24.81']
# Saved predictions for O75121: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for O75132: ['2.3.2.-']
# Saved predictions for O75144: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O75147: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O75326: ['2.7.10.1']
# Saved predictions for O75340: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for O75344: ['5.2.1.8']
# Saved predictions for O75362: ['2.3.2.-']
# Saved predictions for O75396: ['2.3.1.-']
# Saved predictions for O75427: ['3.1.3.16']
# Saved predictions for O75494: ['3.1.3.36']
# Saved predictions for O75628: ['3.6.5.2', '3.6.5.-']
# Saved predictions for O75677: ['2.3.2.27']
# Saved predictions for O75678: ['2.3.2.27']
# Saved predictions for O75679: ['2.3.2.27']
# Saved predictions for O75746: ['5.2.1.8']
# Saved predictions for O75791: ['2.7.10.2']
# Saved predictions for O75832: ['3.5.1.2', '2.4.2.-', '2.4.2.30']
# Saved predictions for O75838: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for O75840: ['2.3.2.-']
# Saved predictions for O75864: ['2.3.1.-', '2.7.11.1']
# Saved predictions for O75871: ['3.2.2.6']
# Saved predictions for O76036: ['3.2.2.6']
# Saved predictions for O76054: ['3.1.3.48']
# Saved predictions for O76081: ['2.7.11.16']
# Saved predictions for O94759: ['3.6.1.45', '3.6.1.-', '3.6.1.77']
# Saved predictions for O94779: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O94826: ['2.4.1.255', '2.3.2.27']
# Saved predictions for O94856: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O94880: ['1.14.11.66', '1.14.11.-', '1.14.11.67']
# Saved predictions for O94887: ['3.1.3.48', '2.7.10.1']
# Saved predictions for O94892: ['2.3.2.-']
# Saved predictions for O94898: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for O94933: ['3.1.3.16']
# Saved predictions for O94991: ['3.1.3.16']
# Saved predictions for O95049: ['2.7.11.1']
# Saved predictions for O95057: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for O95159: ['2.3.2.27']
# Saved predictions for O95185: ['2.7.10.1']
# Saved predictions for O95201: ['2.3.2.-', '2.1.1.-']
# Saved predictions for O95202: ['5.2.1.8', '1.1.5.3']
# Saved predictions for O95235: ['3.6.4.-', '2.7.10.1', '5.6.1.3']
# Saved predictions for O95239: ['3.6.4.-', '2.7.10.1', '5.6.1.3']
# Saved predictions for O95248: ['3.1.3.95']
# Saved predictions for O95297: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O95299: ['2.7.1.74', '2.7.1.113', '2.7.1.76']
# Saved predictions for O95352: ['2.7.7.80', '2.8.1.11']
# Saved predictions for O95365: ['2.3.2.-']
# Saved predictions for O95409: ['2.3.2.-']
# Saved predictions for O95428: ['3.4.24.-', '3.4.24.14']
# Saved predictions for O95503: ['2.3.2.-', '2.1.1.355']
# Saved predictions for O95600: ['2.3.2.-']
# Saved predictions for O95696: ['2.3.2.27']
# Saved predictions for O95716: ['3.6.5.2', '3.6.5.-']
# Saved predictions for O95727: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O95785: ['2.3.2.-']
# Saved predictions for O95801: ['2.4.1.255']
# Saved predictions for O95837: ['3.6.5.-']
# Saved predictions for O95843: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for O95863: ['2.3.2.-']
# Saved predictions for O95931: ['2.3.2.-', '2.1.1.355']
# Saved predictions for O95944: ['3.2.2.6', '3.4.24.-']
# Saved predictions for O95967: ['3.4.24.19', '1.11.1.8']
# Saved predictions for O95994: ['1.8.4.2']
# Saved predictions for O95998: ['3.2.2.6']
# Saved predictions for P00167: ['1.14.19.44', '1.14.19.3', '1.8.3.1']
# Saved predictions for P00451: ['1.11.1.27', '1.11.1.9', '1.16.3.1']
# Saved predictions for P00709: ['3.2.1.17']
# Saved predictions for P00738: ['3.4.21.-', '3.4.21.4', '3.4.21.35']
# Saved predictions for P00739: ['3.4.21.-', '3.4.21.4', '3.4.21.35']
# Saved predictions for P01130: ['3.4.24.19']
# Saved predictions for P01133: ['3.4.24.19', '1.11.1.8']
# Saved predictions for P01266: ['3.1.1.1', '3.1.1.56', '3.1.1.13']
# Saved predictions for P01593: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01594: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01597: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01602: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01615: ['3.2.2.6']
# Saved predictions for P01619: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01699: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01700: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01701: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01704: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01705: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01706: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01709: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01721: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01730: ['2.7.10.1']
# Saved predictions for P01732: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01742: ['3.2.2.6']
# Saved predictions for P01764: ['3.2.2.6']
# Saved predictions for P01768: ['3.2.2.6']
# Saved predictions for P01772: ['3.2.2.6']
# Saved predictions for P01780: ['3.2.2.6']
# Saved predictions for P01814: ['3.2.2.6']
# Saved predictions for P01817: ['3.2.2.6']
# Saved predictions for P01833: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P01850: ['3.2.2.6']
# Saved predictions for P02042: ['1.11.1.-', '1.7.-.-']
# Saved predictions for P02100: ['1.11.1.-', '1.7.-.-']
# Saved predictions for P02585: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P02753: ['5.3.99.2', '1.6.2.-']
# Saved predictions for P02763: ['5.3.99.2']
# Saved predictions for P02787: ['3.4.21.-']
# Saved predictions for P02790: ['3.4.24.-']
# Saved predictions for P02792: ['1.16.3.1']
# Saved predictions for P04217: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P04271: ['5.2.1.8']
# Saved predictions for P04350: ['3.6.5.-']
# Saved predictions for P04632: ['3.1.3.16', '5.2.1.8', '1.1.5.3']
# Saved predictions for P04899: ['3.6.5.-']
# Saved predictions for P05090: ['5.3.99.2']
# Saved predictions for P05109: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P05413: ['5.3.99.2']
# Saved predictions for P05937: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P06312: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P06702: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P06703: ['5.2.1.8']
# Saved predictions for P06731: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P07108: ['5.3.3.8']
# Saved predictions for P07204: ['3.4.24.19']
# Saved predictions for P07225: ['3.4.21.21', '3.4.21.22', '3.4.21.6']
# Saved predictions for P07305: ['2.3.1.48']
# Saved predictions for P07360: ['5.3.99.2', '1.6.2.-']
# Saved predictions for P07437: ['3.6.5.-']
# Saved predictions for P07911: ['3.4.24.19']
# Saved predictions for P08047: ['2.3.2.-']
# Saved predictions for P08048: ['2.3.2.-']
# Saved predictions for P08134: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for P08151: ['2.3.2.-']
# Saved predictions for P08195: ['3.2.1.1']
# Saved predictions for P08238: ['3.6.4.10']
# Saved predictions for P08571: ['2.3.1.-', '2.7.11.1']
# Saved predictions for P08582: ['3.4.21.-']
# Saved predictions for P08637: ['3.2.2.6', '3.4.24.-', '2.7.10.1']
# Saved predictions for P08754: ['3.6.5.-']
# Saved predictions for P08887: ['2.7.10.1', '3.1.3.48']
# Saved predictions for P09326: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P09466: ['5.3.99.2', '1.6.2.-']
# Saved predictions for P09564: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P09913: ['2.4.1.255', '2.3.2.27']
# Saved predictions for P09914: ['2.4.1.255']
# Saved predictions for P0C2W1: ['2.3.2.27']
# Saved predictions for P0C7X2: ['2.3.2.-']
# Saved predictions for P0CG47: ['3.4.19.12']
# Saved predictions for P0CG48: ['3.4.19.12']
# Saved predictions for P0DMV8: ['3.6.4.10']
# Saved predictions for P0DMV9: ['3.6.4.10']
# Saved predictions for P0DP23: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P0DP24: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P0DP25: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P0DPK3: ['1.11.1.8', '3.4.24.19', '3.4.21.104']
# Saved predictions for P0DPK4: ['1.11.1.8', '3.4.24.19', '3.4.21.104']
# Saved predictions for P0DSE1: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P0DSE2: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P0DTU3: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P0DTU4: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P10070: ['2.3.2.-']
# Saved predictions for P10071: ['2.3.2.-']
# Saved predictions for P10073: ['2.3.2.-']
# Saved predictions for P10074: ['2.3.2.-']
# Saved predictions for P10412: ['2.3.1.48']
# Saved predictions for P10599: ['5.3.4.1', '1.8.4.2', '1.11.1.24']
# Saved predictions for P10646: ['1.6.2.-']
# Saved predictions for P10911: ['2.7.11.1']
# Saved predictions for P10915: ['3.2.2.6']
# Saved predictions for P10916: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P10966: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P11171: ['3.1.3.48', '2.7.10.1']
# Saved predictions for P11464: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P11488: ['3.6.5.-']
# Saved predictions for P11912: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P12018: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P12271: ['3.1.3.48']
# Saved predictions for P12314: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P12318: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P12319: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P13591: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for P13682: ['2.3.2.-']
# Saved predictions for P13688: ['2.7.10.1', '3.2.2.6']
# Saved predictions for P13796: ['5.2.1.8']
# Saved predictions for P13797: ['5.2.1.8']
# Saved predictions for P14210: ['3.4.21.-', '3.4.21.7', '3.4.21.73']
# Saved predictions for P14625: ['3.6.4.10']
# Saved predictions for P15090: ['5.3.99.2']
# Saved predictions for P15151: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P15311: ['3.1.3.48', '2.7.10.1']
# Saved predictions for P15313: ['7.1.2.2']
# Saved predictions for P15391: ['3.2.2.6', '3.4.24.-', '2.7.10.1']
# Saved predictions for P15622: ['2.3.2.-']
# Saved predictions for P15822: ['2.3.2.-']
# Saved predictions for P16284: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P16401: ['2.3.1.48']
# Saved predictions for P16402: ['2.3.1.48']
# Saved predictions for P16403: ['2.3.1.48']
# Saved predictions for P16452: ['2.3.2.13', '3.5.1.44', '2.3.1.-']
# Saved predictions for P17010: ['2.3.2.-']
# Saved predictions for P17014: ['2.3.2.-']
# Saved predictions for P17020: ['2.3.2.-', '2.1.1.-']
# Saved predictions for P17021: ['2.3.2.-']
# Saved predictions for P17023: ['2.3.2.-']
# Saved predictions for P17024: ['2.3.2.-']
# Saved predictions for P17027: ['2.3.2.-']
# Saved predictions for P17028: ['2.3.2.-']
# Saved predictions for P17036: ['2.3.2.-']
# Saved predictions for P17041: ['2.3.2.-']
# Saved predictions for P17066: ['3.6.4.10']
# Saved predictions for P17081: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for P17980: ['5.6.1.1', '3.6.4.6', '3.6.4.-']
# Saved predictions for P17987: ['5.6.1.7']
# Saved predictions for P18085: ['3.6.5.2', '2.3.2.27']
# Saved predictions for P18146: ['2.3.2.-']
# Saved predictions for P18627: ['3.2.2.6', '3.4.24.-', '2.7.10.1']
# Saved predictions for P19086: ['3.6.5.-']
# Saved predictions for P19087: ['3.6.5.-']
# Saved predictions for P19105: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P19320: ['2.7.10.1', '3.1.3.48']
# Saved predictions for P19544: ['2.3.2.-']
# Saved predictions for P19652: ['5.3.99.2']
# Saved predictions for P20138: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P20160: ['3.4.21.-', '3.4.21.4', '3.4.21.35']
# Saved predictions for P20273: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P20292: ['1.11.1.-', '2.5.1.18', '2.5.1.-']
# Saved predictions for P20336: ['3.6.5.2', '3.6.5.-']
# Saved predictions for P20337: ['3.6.5.2', '3.6.5.-']
# Saved predictions for P20340: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for P20472: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P20591: ['3.6.5.5']
# Saved predictions for P20592: ['3.6.5.5']
# Saved predictions for P20618: ['3.4.25.1']
# Saved predictions for P20749: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for P20774: ['3.1.3.16']
# Saved predictions for P20916: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P20936: ['3.1.4.11']
# Saved predictions for P21281: ['7.1.2.2']
# Saved predictions for P21579: ['3.1.1.4', '3.1.3.66', '3.1.1.5']
# Saved predictions for P22492: ['2.3.1.48']
# Saved predictions for P22695: ['3.4.24.64', '3.4.24.61', '3.4.24.56']
# Saved predictions for P22891: ['3.4.21.22', '3.4.21.6', '3.4.21.69']
# Saved predictions for P23083: ['3.2.2.6']
# Saved predictions for P23142: ['3.4.24.19']
# Saved predictions for P23258: ['3.6.5.-']
# Saved predictions for P23297: ['5.2.1.8']
# Saved predictions for P23434: ['2.3.1.61']
# Saved predictions for P23588: ['3.1.3.36']
# Saved predictions for P24071: ['3.2.2.6']
# Saved predictions for P24278: ['2.3.2.-', '3.6.1.-']
# Saved predictions for P24844: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P25189: ['3.2.2.6']
# Saved predictions for P25490: ['2.3.2.-']
# Saved predictions for P25705: ['7.1.2.2']
# Saved predictions for P25789: ['3.4.25.1']
# Saved predictions for P25963: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for P26038: ['3.1.3.48', '2.7.10.1']
# Saved predictions for P26368: ['3.1.3.36']
# Saved predictions for P26447: ['5.2.1.8']
# Saved predictions for P26641: ['2.5.1.18', '1.8.-.-', '1.11.1.-']
# Saved predictions for P26927: ['3.4.21.-', '3.4.21.7', '3.4.21.73']
# Saved predictions for P26992: ['3.1.3.48', '2.7.10.1', '3.2.2.6']
# Saved predictions for P27482: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P27540: ['2.3.1.48']
# Saved predictions for P27930: ['2.7.10.1', '3.2.2.6']
# Saved predictions for P28070: ['3.4.25.1']
# Saved predictions for P28676: ['3.1.3.16', '5.2.1.8', '1.1.5.3']
# Saved predictions for P28698: ['2.3.2.-']
# Saved predictions for P29034: ['5.2.1.8']
# Saved predictions for P29373: ['5.3.99.2']
# Saved predictions for P29460: ['3.1.3.48']
# Saved predictions for P30260: ['2.4.1.255', '2.3.2.27']
# Saved predictions for P30626: ['3.1.3.16', '5.2.1.8', '1.1.5.3']
# Saved predictions for P30679: ['3.6.5.-']
# Saved predictions for P31025: ['5.3.99.2']
# Saved predictions for P31151: ['5.2.1.8']
# Saved predictions for P31483: ['2.3.2.27']
# Saved predictions for P31629: ['2.3.2.-']
# Saved predictions for P31930: ['3.4.24.64', '3.4.24.61', '3.4.24.56']
# Saved predictions for P31949: ['5.2.1.8']
# Saved predictions for P31994: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P31995: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P31997: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P32004: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for P32942: ['3.2.2.6']
# Saved predictions for P33176: ['3.6.4.-', '2.7.10.1', '5.6.1.3']
# Saved predictions for P33681: ['3.2.2.6']
# Saved predictions for P33763: ['5.2.1.8']
# Saved predictions for P34931: ['3.6.4.10']
# Saved predictions for P34932: ['3.6.4.10']
# Saved predictions for P35219: ['4.2.1.1', '4.2.1.69']
# Saved predictions for P35226: ['2.3.2.27', '2.3.2.31', '2.3.2.36']
# Saved predictions for P35227: ['2.3.2.27', '2.3.2.31', '2.3.2.36']
# Saved predictions for P35240: ['3.1.3.48', '2.7.10.1']
# Saved predictions for P35241: ['3.1.3.48', '2.7.10.1']
# Saved predictions for P35243: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P35613: ['2.7.10.1', '3.1.3.48', '3.2.2.6']
# Saved predictions for P35789: ['2.3.2.-']
# Saved predictions for P35869: ['2.3.1.48']
# Saved predictions for P35998: ['5.6.1.1', '3.6.4.6', '3.6.4.-']
# Saved predictions for P36268: ['2.3.2.2', '3.4.19.13', '3.4.19.14']
# Saved predictions for P36404: ['3.6.5.2']
# Saved predictions for P36405: ['3.6.5.2', '3.6.5.-']
# Saved predictions for P36508: ['2.3.2.-']
# Saved predictions for P37235: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P38159: ['2.3.2.27']
# Saved predictions for P38646: ['3.6.4.10']
# Saved predictions for P40199: ['2.7.10.1', '3.2.2.6', '3.1.3.48']
# Saved predictions for P40200: ['3.2.2.6', '3.4.24.-', '2.7.10.1']
# Saved predictions for P40227: ['5.6.1.7']
# Saved predictions for P40259: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P40616: ['3.6.5.2', '2.3.2.27', '3.6.5.-']
# Saved predictions for P40617: ['3.6.5.2', '2.3.2.27', '3.6.5.-']
# Saved predictions for P40692: ['3.1.-.-']
# Saved predictions for P41182: ['2.3.2.-', '3.6.1.-']
# Saved predictions for P41208: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P41217: ['3.2.2.6']
# Saved predictions for P41220: ['2.7.11.16']
# Saved predictions for P42081: ['3.2.2.6', '3.4.24.-']
# Saved predictions for P42331: ['2.7.11.1']
# Saved predictions for P42566: ['5.2.1.8', '1.1.5.3']
# Saved predictions for P42658: ['3.4.14.5']
# Saved predictions for P42772: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for P42773: ['3.1.1.4', '3.1.1.5', '3.1.2.2']
# Saved predictions for P43080: ['5.2.1.8', '1.1.5.3', '3.1.3.16']
# Saved predictions for P43121: ['2.7.10.1', '3.2.2.6']
# Saved predictions for P43146: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for P43626: ['3.2.2.6']
# Saved predictions for P43628: ['3.2.2.6']
# Saved predictions for P43629: ['3.2.2.6']
# Saved predictions for P43630: ['3.2.2.6']
# Saved predictions for P43631: ['3.2.2.6']
# Saved predictions for P43632: ['3.2.2.6']
# Saved predictions for P43686: ['5.6.1.1', '3.6.4.6', '3.6.4.-']
# Saved predictions for P45973: ['2.3.2.-', '2.1.1.355']
# Saved predictions for P46199: ['3.6.5.3']
# Saved predictions for P46379: ['3.4.19.12']
# Saved predictions for P48200: ['4.2.1.3']
# Saved predictions for P48307: ['1.6.2.-']
# Saved predictions for P48507: ['1.1.1.54', '1.1.1.-', '1.1.1.300']
# Saved predictions for P48643: ['5.6.1.7']
# Saved predictions for P48723: ['3.6.4.10']
# Saved predictions for P48960: ['3.4.24.19']
# Saved predictions for P49321: ['2.4.1.255']
# Saved predictions for P49368: ['5.6.1.7']
# Saved predictions for P49411: ['3.6.5.-', '3.6.5.3']
# Saved predictions for P49638: ['3.1.3.48']
# Saved predictions for P49703: ['3.6.5.2', '2.3.2.27', '3.6.5.-']
# Saved predictions for P49711: ['2.3.2.-', '2.1.1.-']
# Saved predictions for P49720: ['3.4.25.1']
# Saved predictions for P49721: ['3.4.25.1']
# Saved predictions for P49795: ['2.7.11.16']
# Saved predictions for P49798: ['2.7.11.16']
# Saved predictions for P49910: ['2.3.2.-']
# Saved predictions for P50479: ['2.7.11.1']
# Saved predictions for P50542: ['2.4.1.255']
# Saved predictions for P50895: ['2.7.10.1', '3.2.2.6']
# Saved predictions for P50990: ['5.6.1.7']
# Saved predictions for P50991: ['5.6.1.7']
# Saved predictions for P51151: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for P51157: ['3.6.5.2', '3.6.5.-', '3.6.1.-']
# Saved predictions for P51553: ['1.1.1.42', '1.1.1.41']
# Saved predictions for P51608: ['3.2.2.-']
# Saved predictions for P51665: ['3.4.19.-', '3.4.19.12']
# Saved predictions for P51805: ['2.7.10.1']
# Saved predictions for P51809: ['2.3.1.-']
# Saved predictions for P51814: ['2.3.2.-']
# Saved predictions for P51948: ['2.3.2.27', '2.3.2.36', '2.3.2.31']
# Saved predictions for P51991: ['3.1.3.36']
# Saved predictions for P52179: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for P52198: ['3.6.5.2', '3.6.5.-']
# Saved predictions for P52732: ['3.6.4.-']
# Saved predictions for P52736: ['2.3.2.-']
# Saved predictions for P52738: ['2.3.2.-']
# Saved predictions for P52739: ['2.3.2.-', '3.6.1.-']
# Saved predictions for P52742: ['2.3.2.-']
# Saved predictions for P52744: ['2.3.2.-']
# Saved predictions for P52747: ['2.3.2.-']
# Saved predictions for P53814: ['1.14.13.225']
# Saved predictions for P54277: ['3.1.-.-']
# Saved predictions for P54296: ['2.7.10.1', '3.1.3.48', '1.-.-.-']
# Saved predictions for P54315: ['3.1.1.3', '3.1.1.32', '3.1.1.5']
# Saved predictions for P54652: ['3.6.4.10']

# %%
from neo4j import GraphDatabase
from collections import defaultdict

# Neo4j connection settings
URI = "bolt://localhost:7687"
AUTH = ("neo4j", "12345678")

# Connect to Neo4j
driver = GraphDatabase.driver(URI, auth=AUTH)

# Function to retrieve all proteins with NULL ec_number
def get_unannotated_proteins(tx):
    query = """
    MATCH (p:Protein)
    WHERE p.ec_number IS NULL
    RETURN p.entry AS entry
    """
    result = tx.run(query)
    return [record["entry"] for record in result]

# Perform label propagation for given protein (multi-label)
def annotate_protein_multilabel(tx, entry_id, similarity_threshold=0.2, top_n=3, min_weight=0.0):
    query = """
    MATCH (p:Protein {entry: $entry_id})-[r:SIMILARITY]-(neighbor)
    WHERE r.weight >= $threshold AND neighbor.ec_number IS NOT NULL
    RETURN neighbor.ec_number AS ec, r.weight AS weight
    """
    result = tx.run(query, entry_id=entry_id, threshold=similarity_threshold)
    ec_weights = defaultdict(float)
    for record in result:
        ec_raw = record["ec"]
        weight = record["weight"]
        ec_list = [ec.strip() for ec in ec_raw.split(';')]
        for ec in ec_list:
            ec_weights[ec] += weight

    filtered_ecs = [(ec, weight) for ec, weight in ec_weights.items() if weight >= min_weight]
    sorted_ecs = sorted(filtered_ecs, key=lambda x: x[1], reverse=True)
    top_ecs = [ec for ec, _ in sorted_ecs[:top_n]]
    top1_ec = top_ecs[0] if top_ecs else None

    ec_labels = [ec for ec, _ in sorted_ecs]
    ec_weights_values = [round(weight, 4) for _, weight in sorted_ecs]

    return top_ecs, top1_ec, ec_labels, ec_weights_values

# Save predictions to Neo4j (multi-label + top1 + separate score arrays)
def save_predictions(tx, entry_id, predictions, top1, ec_labels, ec_weights_values):
    tx.run("""
        MATCH (p:Protein {entry: $entry})
        SET p.ec_predictions = $predictions,
            p.ec_prediction_top1 = $top1,
            p.ec_prediction_labels = $labels,
            p.ec_prediction_weights = $weights
    """, entry=entry_id, predictions=predictions, top1=top1, labels=ec_labels, weights=ec_weights_values)

# Run annotation for all unannotated proteins
with driver.session() as session:
    entries = session.execute_read(get_unannotated_proteins)
    print(f"Found {len(entries)} unannotated proteins")

    for entry in entries:
        predicted_ecs, top1_ec, ec_labels, ec_weights_values = session.execute_read(
            annotate_protein_multilabel, entry, 0.2, 3, 0.1)
        if predicted_ecs:
            session.execute_write(save_predictions, entry, predicted_ecs, top1_ec, ec_labels, ec_weights_values)
            print(f"Saved predictions for {entry}: {predicted_ecs} | Top1: {top1_ec} | Labels: {ec_labels} | Weights: {ec_weights_values}")

driver.close()
# Out:
# Found 3281 unannotated proteins
# Saved predictions for A0A024R324: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.45, 0.6, 0.3333]
# Saved predictions for A0A024R7I7: ['3.6.5.2', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-'] | Weights: [8.2905, 0.5]
# Saved predictions for A0A087X0K9: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [0.3684]
# Saved predictions for A0A090N7W4: ['2.7.11.1', '2.7.11.22', '2.7.11.30'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1', '2.7.11.22', '2.7.11.30', '2.7.12.2', '2.7.11.24', '2.7.11.23', '2.7.12.1', '2.7.10.2', '2.7.11.26', '2.7.11.25', '2.7.11.11', '2.7.11.31', '2.7.11.16', '2.7.11.13', '2.7.11.19', '2.7.11.15', '2.7.11.10', '2.7.11.21'] | Weights: [48.7605, 8.5, 4.6861, 4.2333, 3.8631, 3.8333, 3.1429, 2.3873, 1.8095, 1.7333, 1.7143, 1.2, 1.1, 0.6713, 0.6667, 0.6667, 0.4444, 0.4]
# Saved predictions for A0A0C4DGF1: ['3.6.1.-'] | Top1: 3.6.1.- | Labels: ['3.6.1.-'] | Weights: [0.4]
# Saved predictions for A0A0K2S4Q6: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for A0A0S2Z3A9: ['2.4.1.255', '2.3.2.27'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255', '2.3.2.27'] | Weights: [0.5, 0.3333]
# Saved predictions for A0A0S2Z3W6: ['7.2.2.13', '7.2.2.10', '7.6.2.1'] | Top1: 7.2.2.13 | Labels: ['7.2.2.13', '7.2.2.10', '7.6.2.1', '7.2.2.19', '7.2.2.8'] | Weights: [4.0, 3.7363, 3.2, 1.9231, 0.4706]
# Saved predictions for A0A0S2Z4Z8: ['2.7.11.1', '2.7.10.2', '2.7.12.2'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1', '2.7.10.2', '2.7.12.2', '2.7.11.25', '2.7.11.30'] | Weights: [7.3556, 2.1889, 1.2, 0.8182, 0.6154]
# Saved predictions for A0A0S2Z5X4: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for A0A140VK09: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for A0A140VKC4: ['3.2.2.-'] | Top1: 3.2.2.- | Labels: ['3.2.2.-'] | Weights: [0.5]
# Saved predictions for A0A384P5C6: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3125]
# Saved predictions for A0A7I2PJA1: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for A0A7I2R3P8: ['2.3.1.-', '2.7.11.1'] | Top1: 2.3.1.- | Labels: ['2.3.1.-', '2.7.11.1'] | Weights: [0.3636, 0.3636]
# Saved predictions for A0A8I5KZC4: ['2.4.2.-', '2.4.2.30'] | Top1: 2.4.2.- | Labels: ['2.4.2.-', '2.4.2.30'] | Weights: [0.3636, 0.3636]
# Saved predictions for A0A8Q3SHM6: ['3.1.1.13', '3.1.1.1', '3.1.1.56'] | Top1: 3.1.1.13 | Labels: ['3.1.1.13', '3.1.1.1', '3.1.1.56', '3.1.1.3', '3.1.1.6', '3.1.1.84', '3.1.1.8', '3.1.1.7'] | Weights: [1.0, 0.8571, 0.8571, 0.5714, 0.5714, 0.4286, 0.3333, 0.3333]
# Saved predictions for A0AVF1: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.4]
# Saved predictions for A0PJY2: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for A1L4K1: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [1.2029]
# Saved predictions for A2A2Y4: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [1.0, 0.5238]
# Saved predictions for A2RUH7: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for A4D1T9: ['3.4.21.-', '3.4.21.4', '3.4.21.35'] | Top1: 3.4.21.- | Labels: ['3.4.21.-', '3.4.21.4', '3.4.21.35', '3.4.21.71', '3.4.21.118', '3.4.21.46', '3.4.21.77', '3.4.21.20', '3.4.21.79', '3.4.21.78', '3.4.21.59', '3.4.21.39', '3.4.21.117', '3.4.21.37', '3.4.21.70', '3.4.21.10', '3.4.21.76', '3.4.21.27', '3.4.21.34', '3.4.21.106', '3.4.21.122', '3.4.21.43', '3.4.21.73', '3.4.21.41', '3.4.21.7', '3.4.21.42'] | Weights: [4.2747, 1.8095, 1.3333, 1.1429, 0.6667, 0.6667, 0.6667, 0.6667, 0.6667, 0.6667, 0.6667, 0.6667, 0.6667, 0.5714, 0.5714, 0.5714, 0.5714, 0.5, 0.5, 0.4444, 0.3636, 0.3636, 0.3333, 0.3077, 0.3077, 0.3077]
# Saved predictions for A6NGQ3: ['2.7.10.1', '2.7.11.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '2.7.11.1'] | Weights: [11.7593, 1.5758]
# Saved predictions for A6NI73: ['2.7.10.1', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6'] | Weights: [0.3077, 0.3]
# Saved predictions for A6NNZ2: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.1818]
# Saved predictions for A8K4G0: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for A8K8V0: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for A8MTJ3: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.8]
# Saved predictions for A8MU46: ['1.14.13.225'] | Top1: 1.14.13.225 | Labels: ['1.14.13.225'] | Weights: [0.375]
# Saved predictions for A8MVW5: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for A9YTQ3: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.5]
# Saved predictions for B2RXF5: ['2.3.2.-', '3.6.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '3.6.1.-'] | Weights: [0.4, 0.3333]
# Saved predictions for B6A8C7: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3333]
# Saved predictions for D0VY79: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.5]
# Saved predictions for D9ZGF9: ['3.1.-.-'] | Top1: 3.1.-.- | Labels: ['3.1.-.-'] | Weights: [0.8889]
# Saved predictions for K9JA46: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.0]
# Saved predictions for O00139: ['3.6.4.-', '2.7.10.1'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1'] | Weights: [0.8333, 0.7692]
# Saved predictions for O00170: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for O00178: ['3.6.5.-', '3.6.5.3'] | Top1: 3.6.5.- | Labels: ['3.6.5.-', '3.6.5.3'] | Weights: [0.5, 0.4545]
# Saved predictions for O00212: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.45, 0.6, 0.3333]
# Saved predictions for O00221: ['3.1.1.4', '3.1.1.5', '3.1.2.2'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.1.5', '3.1.2.2', '3.5.1.2', '2.4.2.-', '2.4.2.30'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for O00233: ['3.4.21.108'] | Top1: 3.4.21.108 | Labels: ['3.4.21.108'] | Weights: [0.4286]
# Saved predictions for O00241: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for O00264: ['1.14.19.44', '1.14.19.3'] | Top1: 1.14.19.44 | Labels: ['1.14.19.44', '1.14.19.3'] | Weights: [0.4, 0.4]
# Saved predictions for O00327: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.7778]
# Saved predictions for O00330: ['2.3.1.12', '2.3.1.168', '2.3.1.61'] | Top1: 2.3.1.12 | Labels: ['2.3.1.12', '2.3.1.168', '2.3.1.61'] | Weights: [0.8889, 0.7778, 0.5]
# Saved predictions for O00445: ['3.1.1.4', '3.1.3.66', '3.1.1.5'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.3.66', '3.1.1.5'] | Weights: [1.0, 0.5, 0.3333]
# Saved predictions for O00478: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.675]
# Saved predictions for O00481: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.675]
# Saved predictions for O00488: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O00533: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [11.7064, 1.7356, 0.3]
# Saved predictions for O00548: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3125]
# Saved predictions for O00560: ['3.4.21.108'] | Top1: 3.4.21.108 | Labels: ['3.4.21.108'] | Weights: [0.3333]
# Saved predictions for O00623: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.3333]
# Saved predictions for O14511: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [10.6357, 1.0392, 0.3333, 0.3077]
# Saved predictions for O14523: ['3.1.3.66'] | Top1: 3.1.3.66 | Labels: ['3.1.3.66'] | Weights: [0.4]
# Saved predictions for O14530: ['1.11.1.24', '5.3.4.1', '1.8.4.2'] | Top1: 1.11.1.24 | Labels: ['1.11.1.24', '5.3.4.1', '1.8.4.2', '1.11.1.27', '2.3.1.23', '3.1.1.4'] | Weights: [1.2333, 0.7333, 0.4, 0.3333, 0.3333, 0.3333]
# Saved predictions for O14593: ['3.1.1.4', '3.1.1.5', '3.1.2.2'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.1.5', '3.1.2.2', '3.5.1.2', '2.4.2.-', '2.4.2.30'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for O14618: ['1.15.1.1'] | Top1: 1.15.1.1 | Labels: ['1.15.1.1'] | Weights: [1.3333]
# Saved predictions for O14628: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O14782: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Weights: [1.0, 0.8333, 0.3077]
# Saved predictions for O14879: ['2.4.1.255', '2.3.2.27'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255', '2.3.2.27'] | Weights: [0.5, 0.3333]
# Saved predictions for O14901: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O14908: ['3.4.21.108'] | Top1: 3.4.21.108 | Labels: ['3.4.21.108'] | Weights: [0.3333]
# Saved predictions for O14931: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for O14950: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for O14966: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.05, 0.6, 0.3333]
# Saved predictions for O14977: ['4.1.1.17'] | Top1: 4.1.1.17 | Labels: ['4.1.1.17'] | Weights: [0.7778]
# Saved predictions for O14979: ['3.1.3.36'] | Top1: 3.1.3.36 | Labels: ['3.1.3.36'] | Weights: [0.6]
# Saved predictions for O15015: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O15018: ['3.4.21.108'] | Top1: 3.4.21.108 | Labels: ['3.4.21.108'] | Weights: [0.4]
# Saved predictions for O15031: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.45]
# Saved predictions for O15060: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O15062: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O15066: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Weights: [1.0, 0.8333, 0.3077]
# Saved predictions for O15068: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [1.272]
# Saved predictions for O15084: ['3.1.1.4', '3.1.1.5', '3.1.2.2'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.1.5', '3.1.2.2', '3.5.1.2', '2.4.2.-', '2.4.2.30'] | Weights: [0.4, 0.4, 0.4, 0.4, 0.4, 0.4]
# Saved predictions for O15156: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O15173: ['1.14.19.44', '1.14.19.3'] | Top1: 1.14.19.44 | Labels: ['1.14.19.44', '1.14.19.3'] | Weights: [0.4, 0.4]
# Saved predictions for O15182: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for O15197: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [6.1368]
# Saved predictions for O15209: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O15287: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.4]
# Saved predictions for O15372: ['3.4.19.-'] | Top1: 3.4.19.- | Labels: ['3.4.19.-'] | Weights: [1.0286]
# Saved predictions for O15381: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Top1: 5.6.1.1 | Labels: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Weights: [3.022, 0.7418, 0.5]
# Saved predictions for O15389: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for O15391: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for O15394: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [8.1863, 1.3856, 0.3]
# Saved predictions for O15492: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [0.9333]
# Saved predictions for O15519: ['3.4.22.36', '3.4.22.57', '3.4.22.58'] | Top1: 3.4.22.36 | Labels: ['3.4.22.36', '3.4.22.57', '3.4.22.58', '3.4.22.-', '3.4.22.55', '3.4.22.56'] | Weights: [0.4545, 0.4545, 0.4545, 0.4444, 0.4167, 0.4]
# Saved predictions for O15535: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O15540: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.3333]
# Saved predictions for O15553: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [2.2117]
# Saved predictions for O43157: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.4286]
# Saved predictions for O43167: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43169: ['1.14.19.44', '1.14.19.3', '1.8.3.1'] | Top1: 1.14.19.44 | Labels: ['1.14.19.44', '1.14.19.3', '1.8.3.1'] | Weights: [0.3333, 0.3333, 0.3]
# Saved predictions for O43187: ['2.7.11.1', '2.7.10.2'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1', '2.7.10.2'] | Weights: [1.8, 0.3]
# Saved predictions for O43189: ['1.14.11.66', '1.14.11.-', '1.14.11.69'] | Top1: 1.14.11.66 | Labels: ['1.14.11.66', '1.14.11.-', '1.14.11.69'] | Weights: [0.7529, 0.3571, 0.3529]
# Saved predictions for O43291: ['1.6.2.-'] | Top1: 1.6.2.- | Labels: ['1.6.2.-'] | Weights: [0.375]
# Saved predictions for O43296: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43298: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43300: ['3.1.3.16'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16'] | Weights: [0.3]
# Saved predictions for O43309: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43396: ['5.3.4.1', '1.8.4.2'] | Top1: 5.3.4.1 | Labels: ['5.3.4.1', '1.8.4.2'] | Weights: [1.0083, 0.375]
# Saved predictions for O43474: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O43491: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.913, 0.4783]
# Saved predictions for O43572: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [0.3]
# Saved predictions for O43581: ['3.1.3.66'] | Top1: 3.1.3.66 | Labels: ['3.1.3.66'] | Weights: [0.3333]
# Saved predictions for O43623: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for O43670: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43699: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [12.3854, 0.9825, 0.3158]
# Saved predictions for O43745: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for O43765: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.3333]
# Saved predictions for O43809: ['3.6.1.-', '3.6.1.77', '3.6.1.45'] | Top1: 3.6.1.- | Labels: ['3.6.1.-', '3.6.1.77', '3.6.1.45', '3.6.1.10', '3.6.1.52', '3.6.1.59', '3.6.1.61', '3.6.1.62', '3.6.1.56', '3.6.1.17'] | Weights: [1.5667, 0.9, 0.5, 0.4, 0.4, 0.4, 0.4, 0.4, 0.3333, 0.3333]
# Saved predictions for O43819: ['1.11.1.24'] | Top1: 1.11.1.24 | Labels: ['1.11.1.24'] | Weights: [0.3333]
# Saved predictions for O43822: ['2.3.1.-', '2.7.11.1'] | Top1: 2.3.1.- | Labels: ['2.3.1.-', '2.7.11.1'] | Weights: [0.3333, 0.3333]
# Saved predictions for O43829: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O43837: ['1.1.1.42', '1.1.1.41'] | Top1: 1.1.1.42 | Labels: ['1.1.1.42', '1.1.1.41'] | Weights: [1.0, 1.0]
# Saved predictions for O43852: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Weights: [0.6333, 0.5, 0.375]
# Saved predictions for O43865: ['3.13.2.1'] | Top1: 3.13.2.1 | Labels: ['3.13.2.1'] | Weights: [1.0]
# Saved predictions for O43896: ['5.6.1.3', '3.6.4.-'] | Top1: 5.6.1.3 | Labels: ['5.6.1.3', '3.6.4.-'] | Weights: [0.5833, 0.5]
# Saved predictions for O43918: ['1.14.11.-'] | Top1: 1.14.11.- | Labels: ['1.14.11.-'] | Weights: [0.3571]
# Saved predictions for O60256: ['2.7.6.1', '2.4.2.8', '2.4.2.7'] | Top1: 2.7.6.1 | Labels: ['2.7.6.1', '2.4.2.8', '2.4.2.7'] | Weights: [1.3333, 0.6667, 0.3333]
# Saved predictions for O60281: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for O60469: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.6471, 1.8825, 0.3333, 0.3077]
# Saved predictions for O60481: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O60486: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.4]
# Saved predictions for O60487: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for O60494: ['3.4.24.19', '3.4.24.-', '3.4.21.104'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19', '3.4.24.-', '3.4.21.104', '1.11.1.8'] | Weights: [0.5714, 0.4286, 0.4118, 0.3333]
# Saved predictions for O60500: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [8.1863, 1.3856, 0.3]
# Saved predictions for O60667: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for O60706: ['7.6.2.-', '7.6.2.2', '7.6.2.3'] | Top1: 7.6.2.- | Labels: ['7.6.2.-', '7.6.2.2', '7.6.2.3', '7.6.2.1', '3.1.2.-', '7.6.2.8', '5.6.1.6'] | Weights: [4.4348, 3.1015, 2.4924, 1.4242, 1.0, 0.5455, 0.5385]
# Saved predictions for O60759: ['3.4.21.108'] | Top1: 3.4.21.108 | Labels: ['3.4.21.108'] | Weights: [0.3333]
# Saved predictions for O60828: ['2.3.2.26'] | Top1: 2.3.2.26 | Labels: ['2.3.2.26'] | Weights: [0.3333]
# Saved predictions for O60939: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for O75015: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Weights: [0.8081, 0.3636, 0.3077]
# Saved predictions for O75019: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for O75022: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [9.8814, 0.6713, 0.625, 0.3077]
# Saved predictions for O75023: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [9.8814, 0.6713, 0.625, 0.3077]
# Saved predictions for O75027: ['7.6.2.-', '7.6.2.2', '7.6.2.3'] | Top1: 7.6.2.- | Labels: ['7.6.2.-', '7.6.2.2', '7.6.2.3', '7.6.2.1', '3.1.2.-', '7.6.2.8', '5.6.1.6'] | Weights: [5.8247, 3.6833, 2.6, 2.4444, 1.3333, 0.75, 0.5455]
# Saved predictions for O75037: ['2.7.10.1', '3.6.4.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.6.4.-'] | Weights: [0.625, 0.5556]
# Saved predictions for O75051: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.4091]
# Saved predictions for O75054: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for O75077: ['3.4.24.-', '3.4.24.81'] | Top1: 3.4.24.- | Labels: ['3.4.24.-', '3.4.24.81'] | Weights: [2.1667, 0.3333]
# Saved predictions for O75078: ['3.4.24.-', '3.4.24.81'] | Top1: 3.4.24.- | Labels: ['3.4.24.-', '3.4.24.81'] | Weights: [2.3, 0.3077]
# Saved predictions for O75121: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '1.-.-.-', '3.4.24.-'] | Weights: [15.327, 1.2571, 0.7333, 0.4, 0.3333]
# Saved predictions for O75132: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O75144: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for O75147: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for O75326: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.3]
# Saved predictions for O75340: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for O75344: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for O75362: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for O75396: ['2.3.1.-'] | Top1: 2.3.1.- | Labels: ['2.3.1.-'] | Weights: [0.5]
# Saved predictions for O75427: ['3.1.3.16'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16'] | Weights: [0.3636]
# Saved predictions for O75494: ['3.1.3.36'] | Top1: 3.1.3.36 | Labels: ['3.1.3.36'] | Weights: [0.6]
# Saved predictions for O75628: ['3.6.5.2', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-'] | Weights: [7.5143, 0.5]
# Saved predictions for O75677: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [2.5382]
# Saved predictions for O75678: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [2.0754]
# Saved predictions for O75679: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [2.5382]
# Saved predictions for O75746: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3]
# Saved predictions for O75791: ['2.7.10.2'] | Top1: 2.7.10.2 | Labels: ['2.7.10.2'] | Weights: [0.6154]
# Saved predictions for O75832: ['3.5.1.2', '2.4.2.-', '2.4.2.30'] | Top1: 3.5.1.2 | Labels: ['3.5.1.2', '2.4.2.-', '2.4.2.30', '3.1.1.4', '3.1.1.5', '3.1.2.2'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for O75838: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for O75840: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O75864: ['2.3.1.-', '2.7.11.1'] | Top1: 2.3.1.- | Labels: ['2.3.1.-', '2.7.11.1'] | Weights: [0.3333, 0.3333]
# Saved predictions for O75871: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for O76036: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3333]
# Saved predictions for O76054: ['3.1.3.48'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48'] | Weights: [0.3077]
# Saved predictions for O76081: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [1.0417]
# Saved predictions for O94759: ['3.6.1.45', '3.6.1.-', '3.6.1.77'] | Top1: 3.6.1.45 | Labels: ['3.6.1.45', '3.6.1.-', '3.6.1.77', '2.7.11.1'] | Weights: [0.3333, 0.3333, 0.3333, 0.3]
# Saved predictions for O94779: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.6832, 2.322, 0.3529, 0.3333]
# Saved predictions for O94826: ['2.4.1.255', '2.3.2.27'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255', '2.3.2.27'] | Weights: [0.5, 0.3333]
# Saved predictions for O94856: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [11.7064, 1.7356, 0.3]
# Saved predictions for O94880: ['1.14.11.66', '1.14.11.-', '1.14.11.67'] | Top1: 1.14.11.66 | Labels: ['1.14.11.66', '1.14.11.-', '1.14.11.67', '2.3.2.27', '1.14.11.69'] | Weights: [0.7738, 0.5, 0.3571, 0.3571, 0.3571]
# Saved predictions for O94887: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.8077, 0.4231]
# Saved predictions for O94892: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O94898: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [8.5196, 0.9316, 0.625]
# Saved predictions for O94933: ['3.1.3.16'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16'] | Weights: [0.3]
# Saved predictions for O94991: ['3.1.3.16'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16'] | Weights: [0.3]
# Saved predictions for O95049: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [0.4118]
# Saved predictions for O95057: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [11.75, 1.0, 0.3333]
# Saved predictions for O95159: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.6667]
# Saved predictions for O95185: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.3]
# Saved predictions for O95201: ['2.3.2.-', '2.1.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.-'] | Weights: [0.3333, 0.3333]
# Saved predictions for O95202: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for O95235: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Weights: [0.6667, 0.6154, 0.3077]
# Saved predictions for O95239: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Weights: [1.0, 0.8333, 0.3077]
# Saved predictions for O95248: ['3.1.3.95'] | Top1: 3.1.3.95 | Labels: ['3.1.3.95'] | Weights: [1.0]
# Saved predictions for O95297: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for O95299: ['2.7.1.74', '2.7.1.113', '2.7.1.76'] | Top1: 2.7.1.74 | Labels: ['2.7.1.74', '2.7.1.113', '2.7.1.76', '2.7.1.-', '2.7.1.21'] | Weights: [1.2, 0.6, 0.6, 0.6, 0.6]
# Saved predictions for O95352: ['2.7.7.80', '2.8.1.11'] | Top1: 2.7.7.80 | Labels: ['2.7.7.80', '2.8.1.11'] | Weights: [0.3, 0.3]
# Saved predictions for O95365: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for O95409: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O95428: ['3.4.24.-', '3.4.24.14'] | Top1: 3.4.24.- | Labels: ['3.4.24.-', '3.4.24.14'] | Weights: [0.3333, 0.3182]
# Saved predictions for O95503: ['2.3.2.-', '2.1.1.355'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.355'] | Weights: [0.75, 0.3077]
# Saved predictions for O95600: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for O95696: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.4444]
# Saved predictions for O95716: ['3.6.5.2', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-'] | Weights: [8.2905, 0.5]
# Saved predictions for O95727: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for O95785: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for O95801: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.4]
# Saved predictions for O95837: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [3.2]
# Saved predictions for O95843: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for O95863: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for O95931: ['2.3.2.-', '2.1.1.355'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.355'] | Weights: [0.75, 0.3077]
# Saved predictions for O95944: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for O95967: ['3.4.24.19', '1.11.1.8'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19', '1.11.1.8'] | Weights: [0.3529, 0.3125]
# Saved predictions for O95994: ['1.8.4.2'] | Top1: 1.8.4.2 | Labels: ['1.8.4.2'] | Weights: [0.4]
# Saved predictions for O95998: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P00167: ['1.14.19.44', '1.14.19.3', '1.8.3.1'] | Top1: 1.14.19.44 | Labels: ['1.14.19.44', '1.14.19.3', '1.8.3.1'] | Weights: [0.3333, 0.3333, 0.3]
# Saved predictions for P00451: ['1.11.1.27', '1.11.1.9', '1.16.3.1'] | Top1: 1.11.1.27 | Labels: ['1.11.1.27', '1.11.1.9', '1.16.3.1', '1.16.3.4'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for P00709: ['3.2.1.17'] | Top1: 3.2.1.17 | Labels: ['3.2.1.17'] | Weights: [0.6]
# Saved predictions for P00738: ['3.4.21.-', '3.4.21.4', '3.4.21.35'] | Top1: 3.4.21.- | Labels: ['3.4.21.-', '3.4.21.4', '3.4.21.35', '3.4.21.71', '3.4.21.43', '3.4.21.46', '3.4.21.77', '3.4.21.20', '3.4.21.79', '3.4.21.78', '3.4.21.59', '3.4.21.39', '3.4.21.117', '3.4.21.118', '3.4.21.42', '3.4.21.41', '3.4.21.37', '3.4.21.70', '3.4.21.10', '3.4.21.76', '3.4.21.47', '3.4.21.27', '3.4.21.34', '3.4.21.104', '3.4.21.106', '3.4.21.122'] | Weights: [3.6713, 1.3889, 1.0, 0.8889, 0.5455, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.4615, 0.4615, 0.4444, 0.4444, 0.4444, 0.4444, 0.4167, 0.4, 0.4, 0.4, 0.3636, 0.3077]
# Saved predictions for P00739: ['3.4.21.-', '3.4.21.4', '3.4.21.35'] | Top1: 3.4.21.- | Labels: ['3.4.21.-', '3.4.21.4', '3.4.21.35', '3.4.21.71', '3.4.21.46', '3.4.21.77', '3.4.21.20', '3.4.21.79', '3.4.21.78', '3.4.21.59', '3.4.21.39', '3.4.21.117', '3.4.21.118', '3.4.21.37', '3.4.21.70', '3.4.21.10', '3.4.21.76', '3.4.21.43', '3.4.21.27', '3.4.21.34', '3.4.21.106', '3.4.21.42', '3.4.21.41', '3.4.21.104', '3.4.21.47', '3.4.21.122'] | Weights: [3.5761, 1.3889, 1.0, 0.8889, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.4444, 0.4444, 0.4444, 0.4444, 0.4167, 0.4, 0.4, 0.3636, 0.3571, 0.3571, 0.3125, 0.3077, 0.3077]
# Saved predictions for P01130: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3158]
# Saved predictions for P01133: ['3.4.24.19', '1.11.1.8'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19', '1.11.1.8'] | Weights: [0.3529, 0.3125]
# Saved predictions for P01266: ['3.1.1.1', '3.1.1.56', '3.1.1.13'] | Top1: 3.1.1.1 | Labels: ['3.1.1.1', '3.1.1.56', '3.1.1.13', '3.1.1.84'] | Weights: [0.6, 0.6, 0.3, 0.3]
# Saved predictions for P01593: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01594: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01597: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01602: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01615: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01619: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01699: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01700: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01701: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01704: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01705: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01706: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01709: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01721: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01730: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [1.5]
# Saved predictions for P01732: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01742: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01764: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01768: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01772: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01780: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01814: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01817: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P01833: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P01850: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P02042: ['1.11.1.-', '1.7.-.-'] | Top1: 1.11.1.- | Labels: ['1.11.1.-', '1.7.-.-'] | Weights: [0.3333, 0.3333]
# Saved predictions for P02100: ['1.11.1.-', '1.7.-.-'] | Top1: 1.11.1.- | Labels: ['1.11.1.-', '1.7.-.-'] | Weights: [0.3333, 0.3333]
# Saved predictions for P02585: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P02753: ['5.3.99.2', '1.6.2.-'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2', '1.6.2.-'] | Weights: [0.5, 0.3]
# Saved predictions for P02763: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.4]
# Saved predictions for P02787: ['3.4.21.-'] | Top1: 3.4.21.- | Labels: ['3.4.21.-'] | Weights: [0.6]
# Saved predictions for P02790: ['3.4.24.-'] | Top1: 3.4.24.- | Labels: ['3.4.24.-'] | Weights: [0.3333]
# Saved predictions for P02792: ['1.16.3.1'] | Top1: 1.16.3.1 | Labels: ['1.16.3.1'] | Weights: [1.0]
# Saved predictions for P04217: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P04271: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P04350: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.1818]
# Saved predictions for P04632: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Weights: [0.6333, 0.5, 0.375]
# Saved predictions for P04899: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.8]
# Saved predictions for P05090: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.4286]
# Saved predictions for P05109: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for P05413: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.3333]
# Saved predictions for P05937: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for P06312: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P06702: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for P06703: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P06731: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P07108: ['5.3.3.8'] | Top1: 5.3.3.8 | Labels: ['5.3.3.8'] | Weights: [0.5]
# Saved predictions for P07204: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3158]
# Saved predictions for P07225: ['3.4.21.21', '3.4.21.22', '3.4.21.6'] | Top1: 3.4.21.21 | Labels: ['3.4.21.21', '3.4.21.22', '3.4.21.6', '3.4.21.69', '3.4.24.19'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3]
# Saved predictions for P07305: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.3]
# Saved predictions for P07360: ['5.3.99.2', '1.6.2.-'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2', '1.6.2.-'] | Weights: [0.5, 0.4444]
# Saved predictions for P07437: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.1818]
# Saved predictions for P07911: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3333]
# Saved predictions for P08047: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for P08048: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P08134: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.45, 0.6, 0.3333]
# Saved predictions for P08151: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P08195: ['3.2.1.1'] | Top1: 3.2.1.1 | Labels: ['3.2.1.1'] | Weights: [1.5]
# Saved predictions for P08238: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.0]
# Saved predictions for P08571: ['2.3.1.-', '2.7.11.1'] | Top1: 2.3.1.- | Labels: ['2.3.1.-', '2.7.11.1'] | Weights: [0.3333, 0.3333]
# Saved predictions for P08582: ['3.4.21.-'] | Top1: 3.4.21.- | Labels: ['3.4.21.-'] | Weights: [0.75]
# Saved predictions for P08637: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Weights: [0.8081, 0.3636, 0.3077]
# Saved predictions for P08754: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.8]
# Saved predictions for P08887: ['2.7.10.1', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48'] | Weights: [3.4652, 1.5808]
# Saved predictions for P09326: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P09466: ['5.3.99.2', '1.6.2.-'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2', '1.6.2.-'] | Weights: [0.8, 0.3]
# Saved predictions for P09564: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P09913: ['2.4.1.255', '2.3.2.27'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255', '2.3.2.27'] | Weights: [0.5, 0.3333]
# Saved predictions for P09914: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.4]
# Saved predictions for P0C2W1: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.3333]
# Saved predictions for P0C7X2: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P0CG47: ['3.4.19.12'] | Top1: 3.4.19.12 | Labels: ['3.4.19.12'] | Weights: [0.3]
# Saved predictions for P0CG48: ['3.4.19.12'] | Top1: 3.4.19.12 | Labels: ['3.4.19.12'] | Weights: [0.3]
# Saved predictions for P0DMV8: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.8333]
# Saved predictions for P0DMV9: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.8333]
# Saved predictions for P0DP23: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P0DP24: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P0DP25: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P0DPK3: ['1.11.1.8', '3.4.24.19', '3.4.21.104'] | Top1: 1.11.1.8 | Labels: ['1.11.1.8', '3.4.24.19', '3.4.21.104', '3.4.24.-'] | Weights: [0.4545, 0.3846, 0.3333, 0.3333]
# Saved predictions for P0DPK4: ['1.11.1.8', '3.4.24.19', '3.4.21.104'] | Top1: 1.11.1.8 | Labels: ['1.11.1.8', '3.4.24.19', '3.4.21.104', '3.4.24.-'] | Weights: [0.4545, 0.3846, 0.3333, 0.3333]
# Saved predictions for P0DSE1: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P0DSE2: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P0DTU3: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P0DTU4: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P10070: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P10071: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P10073: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P10074: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P10412: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.3]
# Saved predictions for P10599: ['5.3.4.1', '1.8.4.2', '1.11.1.24'] | Top1: 5.3.4.1 | Labels: ['5.3.4.1', '1.8.4.2', '1.11.1.24'] | Weights: [1.3036, 0.5, 0.3333]
# Saved predictions for P10646: ['1.6.2.-'] | Top1: 1.6.2.- | Labels: ['1.6.2.-'] | Weights: [0.3]
# Saved predictions for P10911: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [0.6325]
# Saved predictions for P10915: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3077]
# Saved predictions for P10916: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P10966: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P11171: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.875, 0.4583]
# Saved predictions for P11464: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P11488: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.8]
# Saved predictions for P11912: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for P12018: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P12271: ['3.1.3.48'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48'] | Weights: [0.4]
# Saved predictions for P12314: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [9.8814, 0.6713, 0.625, 0.3077]
# Saved predictions for P12318: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for P12319: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for P13591: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for P13682: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P13688: ['2.7.10.1', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6'] | Weights: [4.098, 0.3333]
# Saved predictions for P13796: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3]
# Saved predictions for P13797: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3]
# Saved predictions for P14210: ['3.4.21.-', '3.4.21.7', '3.4.21.73'] | Top1: 3.4.21.- | Labels: ['3.4.21.-', '3.4.21.7', '3.4.21.73', '3.4.21.68', '3.4.21.5', '3.4.21.38', '3.4.21.27', '3.4.21.34'] | Weights: [0.9505, 0.6667, 0.5, 0.4444, 0.4, 0.381, 0.3333, 0.3333]
# Saved predictions for P14625: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.0]
# Saved predictions for P15090: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.3333]
# Saved predictions for P15151: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P15311: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.7846, 0.5652]
# Saved predictions for P15313: ['7.1.2.2'] | Top1: 7.1.2.2 | Labels: ['7.1.2.2'] | Weights: [0.8013]
# Saved predictions for P15391: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Weights: [0.8081, 0.3636, 0.3077]
# Saved predictions for P15622: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P15822: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P16284: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P16401: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.3]
# Saved predictions for P16402: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.3]
# Saved predictions for P16403: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.3]
# Saved predictions for P16452: ['2.3.2.13', '3.5.1.44', '2.3.1.-'] | Top1: 2.3.2.13 | Labels: ['2.3.2.13', '3.5.1.44', '2.3.1.-', '3.4.-.-'] | Weights: [8.0, 3.0, 1.0, 1.0]
# Saved predictions for P17010: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P17014: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P17020: ['2.3.2.-', '2.1.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.-'] | Weights: [0.5, 0.4286]
# Saved predictions for P17021: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P17023: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P17024: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P17027: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P17028: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P17036: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P17041: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for P17066: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.8333]
# Saved predictions for P17081: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.45, 0.6, 0.3333]
# Saved predictions for P17980: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Top1: 5.6.1.1 | Labels: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Weights: [3.022, 0.7418, 0.3846]
# Saved predictions for P17987: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.3636]
# Saved predictions for P18085: ['3.6.5.2', '2.3.2.27'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '2.3.2.27'] | Weights: [1.0, 0.3333]
# Saved predictions for P18146: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.75]
# Saved predictions for P18627: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Weights: [1.125, 0.3636, 0.3077]
# Saved predictions for P19086: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [2.8]
# ...
# Saved predictions for P26992: ['3.1.3.48', '2.7.10.1', '3.2.2.6'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1', '3.2.2.6'] | Weights: [1.6026, 0.6875, 0.3077]
# Saved predictions for P27482: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P27540: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.7778]
# Saved predictions for P27930: ['2.7.10.1', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6'] | Weights: [3.2423, 0.8782]
# Saved predictions for P28070: ['3.4.25.1'] | Top1: 3.4.25.1 | Labels: ['3.4.25.1'] | Weights: [3.9048]
# Saved predictions for P28676: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Weights: [0.6333, 0.5, 0.375]
# Saved predictions for P28698: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P29034: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P29373: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.3333]
# Saved predictions for P29460: ['3.1.3.48'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48'] | Weights: [0.9825]
# Saved predictions for P30260: ['2.4.1.255', '2.3.2.27'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255', '2.3.2.27'] | Weights: [0.5, 0.3333]
# Saved predictions for P30626: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Top1: 3.1.3.16 | Labels: ['3.1.3.16', '5.2.1.8', '1.1.5.3'] | Weights: [0.6333, 0.5, 0.375]
# Saved predictions for P30679: ['3.6.5.-'] | Top1: 3.6.5.- | Labels: ['3.6.5.-'] | Weights: [3.2]
# Saved predictions for P31025: ['5.3.99.2'] | Top1: 5.3.99.2 | Labels: ['5.3.99.2'] | Weights: [0.6]
# Saved predictions for P31151: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P31483: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.3077]
# Saved predictions for P31629: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.5]
# Saved predictions for P31930: ['3.4.24.64', '3.4.24.61', '3.4.24.56'] | Top1: 3.4.24.64 | Labels: ['3.4.24.64', '3.4.24.61', '3.4.24.56'] | Weights: [0.8, 0.4286, 0.375]
# Saved predictions for P31949: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P31994: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for P31995: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [9.8429, 0.9792, 0.7333, 0.3333, 0.3125]
# Saved predictions for P31997: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P32004: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Weights: [9.8402, 1.7706, 0.3158]
# Saved predictions for P32942: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3077]
# Saved predictions for P33176: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Top1: 3.6.4.- | Labels: ['3.6.4.-', '2.7.10.1', '5.6.1.3'] | Weights: [1.0, 0.8333, 0.3077]
# Saved predictions for P33681: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3077]
# Saved predictions for P33763: ['5.2.1.8'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8'] | Weights: [0.3333]
# Saved predictions for P34931: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.8333]
# Saved predictions for P34932: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.5476]
# Saved predictions for P35219: ['4.2.1.1', '4.2.1.69'] | Top1: 4.2.1.1 | Labels: ['4.2.1.1', '4.2.1.69'] | Weights: [6.1333, 1.6]
# Saved predictions for P35226: ['2.3.2.27', '2.3.2.31', '2.3.2.36'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27', '2.3.2.31', '2.3.2.36', '2.3.2.-', '3.1.-.-'] | Weights: [4.9893, 0.4286, 0.4286, 0.375, 0.3]
# Saved predictions for P35227: ['2.3.2.27', '2.3.2.31', '2.3.2.36'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27', '2.3.2.31', '2.3.2.36', '2.3.2.-', '3.1.-.-'] | Weights: [4.9893, 0.4286, 0.4286, 0.375, 0.3]
# Saved predictions for P35240: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.7846, 0.5652]
# Saved predictions for P35241: ['3.1.3.48', '2.7.10.1'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48', '2.7.10.1'] | Weights: [0.7846, 0.5652]
# Saved predictions for P35243: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P35613: ['2.7.10.1', '3.1.3.48', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '3.2.2.6', '3.4.24.-', '1.-.-.-'] | Weights: [11.7857, 1.0476, 0.8081, 0.3636, 0.3333]
# Saved predictions for P35789: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P35869: ['2.3.1.48'] | Top1: 2.3.1.48 | Labels: ['2.3.1.48'] | Weights: [0.5455]
# Saved predictions for P35998: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Top1: 5.6.1.1 | Labels: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Weights: [3.022, 0.7418, 0.3846]
# Saved predictions for P36268: ['2.3.2.2', '3.4.19.13', '3.4.19.14'] | Top1: 2.3.2.2 | Labels: ['2.3.2.2', '3.4.19.13', '3.4.19.14'] | Weights: [3.0, 3.0, 2.0]
# Saved predictions for P36404: ['3.6.5.2'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2'] | Weights: [1.0]
# Saved predictions for P36405: ['3.6.5.2', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-'] | Weights: [3.8667, 0.3333]
# Saved predictions for P36508: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for P37235: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P38159: ['2.3.2.27'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27'] | Weights: [0.3333]
# Saved predictions for P38646: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.5476]
# Saved predictions for P40199: ['2.7.10.1', '3.2.2.6', '3.1.3.48'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6', '3.1.3.48', '3.4.24.-'] | Weights: [6.2946, 0.6713, 0.625, 0.3077]
# Saved predictions for P40200: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-', '2.7.10.1'] | Weights: [0.8081, 0.3636, 0.3077]
# Saved predictions for P40227: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.4]
# Saved predictions for P40259: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.7333, 0.3333]
# Saved predictions for P40616: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Weights: [3.8667, 0.3636, 0.3333]
# Saved predictions for P40617: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Weights: [3.8667, 0.3636, 0.3333]
# Saved predictions for P40692: ['3.1.-.-'] | Top1: 3.1.-.- | Labels: ['3.1.-.-'] | Weights: [0.5833]
# Saved predictions for P41182: ['2.3.2.-', '3.6.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '3.6.1.-'] | Weights: [0.4, 0.3333]
# Saved predictions for P41208: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for P41217: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3333]
# Saved predictions for P41220: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [0.3]
# Saved predictions for P42081: ['3.2.2.6', '3.4.24.-'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6', '3.4.24.-'] | Weights: [0.6713, 0.3077]
# Saved predictions for P42331: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [0.3077]
# Saved predictions for P42566: ['5.2.1.8', '1.1.5.3'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3'] | Weights: [0.375, 0.3]
# Saved predictions for P42658: ['3.4.14.5'] | Top1: 3.4.14.5 | Labels: ['3.4.14.5'] | Weights: [0.8]
# Saved predictions for P42772: ['3.1.1.4', '3.1.1.5', '3.1.2.2'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.1.5', '3.1.2.2', '3.5.1.2', '2.4.2.-', '2.4.2.30'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for P42773: ['3.1.1.4', '3.1.1.5', '3.1.2.2'] | Top1: 3.1.1.4 | Labels: ['3.1.1.4', '3.1.1.5', '3.1.2.2', '3.5.1.2', '2.4.2.-', '2.4.2.30'] | Weights: [0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for P43080: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Top1: 5.2.1.8 | Labels: ['5.2.1.8', '1.1.5.3', '3.1.3.16'] | Weights: [0.4286, 0.3333, 0.3]
# Saved predictions for P43121: ['2.7.10.1', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6'] | Weights: [0.3333, 0.3333]
# Saved predictions for P43146: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for P43626: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43628: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43629: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43630: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43631: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43632: ['3.2.2.6'] | Top1: 3.2.2.6 | Labels: ['3.2.2.6'] | Weights: [0.3]
# Saved predictions for P43686: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Top1: 5.6.1.1 | Labels: ['5.6.1.1', '3.6.4.6', '3.6.4.-'] | Weights: [3.022, 0.7418, 0.3846]
# Saved predictions for P45973: ['2.3.2.-', '2.1.1.355'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.355'] | Weights: [0.5556, 0.3077]
# Saved predictions for P46199: ['3.6.5.3'] | Top1: 3.6.5.3 | Labels: ['3.6.5.3'] | Weights: [0.6364]
# Saved predictions for P46379: ['3.4.19.12'] | Top1: 3.4.19.12 | Labels: ['3.4.19.12'] | Weights: [0.3]
# Saved predictions for P48200: ['4.2.1.3'] | Top1: 4.2.1.3 | Labels: ['4.2.1.3'] | Weights: [1.0]
# Saved predictions for P48307: ['1.6.2.-'] | Top1: 1.6.2.- | Labels: ['1.6.2.-'] | Weights: [0.3]
# Saved predictions for P48507: ['1.1.1.54', '1.1.1.-', '1.1.1.300'] | Top1: 1.1.1.54 | Labels: ['1.1.1.54', '1.1.1.-', '1.1.1.300', '1.1.1.357', '1.1.1.53', '1.1.1.62', '1.-.-.-', '1.1.1.64', '1.1.1.372', '1.1.1.209', '1.1.1.210', '1.1.1.n11', '1.1.1.216', '1.1.1.21', '1.3.1.3', '1.1.1.112', '1.3.1.20', '1.1.1.19', '1.1.1.2', '1.1.1.20', '1.6.-.-', '1.1.1.225', '1.1.1.51', '1.1.1.188', '1.1.1.239'] | Weights: [1.5333, 1.4, 1.2, 1.0, 1.0, 1.0, 0.8333, 0.7333, 0.7333, 0.6667, 0.6667, 0.5, 0.4, 0.4, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333]
# Saved predictions for P48643: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.3636]
# Saved predictions for P48723: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [0.9286]
# Saved predictions for P48960: ['3.4.24.19'] | Top1: 3.4.24.19 | Labels: ['3.4.24.19'] | Weights: [0.3158]
# Saved predictions for P49321: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.3333]
# Saved predictions for P49368: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.3636]
# Saved predictions for P49411: ['3.6.5.-', '3.6.5.3'] | Top1: 3.6.5.- | Labels: ['3.6.5.-', '3.6.5.3'] | Weights: [0.4615, 0.3333]
# Saved predictions for P49638: ['3.1.3.48'] | Top1: 3.1.3.48 | Labels: ['3.1.3.48'] | Weights: [0.4]
# Saved predictions for P49703: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '2.3.2.27', '3.6.5.-'] | Weights: [3.8667, 0.3636, 0.3333]
# Saved predictions for P49711: ['2.3.2.-', '2.1.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '2.1.1.-'] | Weights: [0.5, 0.4286]
# Saved predictions for P49720: ['3.4.25.1'] | Top1: 3.4.25.1 | Labels: ['3.4.25.1'] | Weights: [3.9048]
# Saved predictions for P49721: ['3.4.25.1'] | Top1: 3.4.25.1 | Labels: ['3.4.25.1'] | Weights: [3.9048]
# Saved predictions for P49795: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [0.9333]
# Saved predictions for P49798: ['2.7.11.16'] | Top1: 2.7.11.16 | Labels: ['2.7.11.16'] | Weights: [0.3]
# Saved predictions for P49910: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P50479: ['2.7.11.1'] | Top1: 2.7.11.1 | Labels: ['2.7.11.1'] | Weights: [0.9]
# Saved predictions for P50542: ['2.4.1.255'] | Top1: 2.4.1.255 | Labels: ['2.4.1.255'] | Weights: [0.4]
# Saved predictions for P50895: ['2.7.10.1', '3.2.2.6'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.2.2.6'] | Weights: [0.3333, 0.3333]
# Saved predictions for P50990: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.4444]
# Saved predictions for P50991: ['5.6.1.7'] | Top1: 5.6.1.7 | Labels: ['5.6.1.7'] | Weights: [0.3636]
# Saved predictions for P51151: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [9.05, 0.6, 0.3333]
# Saved predictions for P51157: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-', '3.6.1.-'] | Weights: [11.4, 0.75, 0.4]
# Saved predictions for P51553: ['1.1.1.42', '1.1.1.41'] | Top1: 1.1.1.42 | Labels: ['1.1.1.42', '1.1.1.41'] | Weights: [1.0, 1.0]
# Saved predictions for P51608: ['3.2.2.-'] | Top1: 3.2.2.- | Labels: ['3.2.2.-'] | Weights: [0.5]
# Saved predictions for P51665: ['3.4.19.-', '3.4.19.12'] | Top1: 3.4.19.- | Labels: ['3.4.19.-', '3.4.19.12'] | Weights: [0.7333, 0.6]
# Saved predictions for P51805: ['2.7.10.1'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1'] | Weights: [0.4286]
# Saved predictions for P51809: ['2.3.1.-'] | Top1: 2.3.1.- | Labels: ['2.3.1.-'] | Weights: [0.5]
# Saved predictions for P51814: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P51948: ['2.3.2.27', '2.3.2.36', '2.3.2.31'] | Top1: 2.3.2.27 | Labels: ['2.3.2.27', '2.3.2.36', '2.3.2.31', '2.3.2.-'] | Weights: [2.7167, 0.3333, 0.3333, 0.3]
# Saved predictions for P51991: ['3.1.3.36'] | Top1: 3.1.3.36 | Labels: ['3.1.3.36'] | Weights: [0.6]
# Saved predictions for P52179: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for P52198: ['3.6.5.2', '3.6.5.-'] | Top1: 3.6.5.2 | Labels: ['3.6.5.2', '3.6.5.-'] | Weights: [7.8143, 0.5]
# Saved predictions for P52732: ['3.6.4.-'] | Top1: 3.6.4.- | Labels: ['3.6.4.-'] | Weights: [0.5]
# Saved predictions for P52736: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P52738: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.3333]
# Saved predictions for P52739: ['2.3.2.-', '3.6.1.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-', '3.6.1.-'] | Weights: [0.4, 0.3333]
# Saved predictions for P52742: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.4]
# Saved predictions for P52744: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for P52747: ['2.3.2.-'] | Top1: 2.3.2.- | Labels: ['2.3.2.-'] | Weights: [0.6667]
# Saved predictions for P53814: ['1.14.13.225'] | Top1: 1.14.13.225 | Labels: ['1.14.13.225'] | Weights: [0.3333]
# Saved predictions for P54277: ['3.1.-.-'] | Top1: 3.1.-.- | Labels: ['3.1.-.-'] | Weights: [0.5385]
# Saved predictions for P54296: ['2.7.10.1', '3.1.3.48', '1.-.-.-'] | Top1: 2.7.10.1 | Labels: ['2.7.10.1', '3.1.3.48', '1.-.-.-', '3.2.2.6'] | Weights: [11.0107, 1.8825, 0.3333, 0.3077]
# Saved predictions for P54315: ['3.1.1.3', '3.1.1.32', '3.1.1.5'] | Top1: 3.1.1.3 | Labels: ['3.1.1.3', '3.1.1.32', '3.1.1.5', '3.1.1.34', '3.1.1.26'] | Weights: [6.1111, 5.2222, 4.4444, 1.5556, 1.0]
# Saved predictions for P54652: ['3.6.4.10'] | Top1: 3.6.4.10 | Labels: ['3.6.4.10'] | Weights: [1.8333]
